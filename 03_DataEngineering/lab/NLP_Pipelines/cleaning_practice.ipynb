# %% [markdown]
# # Cleaning Quiz: Udacity's Course Catalog
# It's your turn! Udacity's [course catalog page](https://www.udacity.com/courses/all) has changed since the last video was filmed. One notable change is the introduction of  _schools_.
#
# In this activity, you're going to perform similar actions with BeautifulSoup to extract the following information from each course listing on the page:
# 1. The course name - e.g. "Data Analyst"
# 2. The school the course belongs to - e.g. "School of Data Science"
#
# **Note: All solution notebooks can be found by clicking on the Jupyter icon on the top left of this workspace.**

# %% [markdown]
# ### Step 1: Get text from Udacity's course catalog web page
# You can use the `requests` library to do this.
#
# You may have to scroll down past the javascript and CSS in the output of the last cell in this section to see the text.

# %% [markdown]
# **UPDATE: I had to change the web page used for this notebook because Udacity uses Javascript to generate the course list; BeautifulSoup cannot deal with pages generated with Javascript after the HTML code is fetched.**

# %%
# import statements
import requests 
from bs4 import BeautifulSoup

# %%
# fetch web page
#r = requests.get('https://www.udacity.com/courses/all')
r = requests.get('https://learndataengineering.com/p/all-courses')

# %%
# display text from web page
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <link href='https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:32,height:32/https://www.filepicker.io/api/file/pEKwD6EKSGgLHDxaM9yA' rel='icon' type='image/png'>
# <link href='https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:72,height:72/https://www.filepicker.io/api/file/pEKwD6EKSGgLHDxaM9yA' rel='apple-touch-icon' type='image/png'>
# <link href='https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:144,height:144/https://www.filepicker.io/api/file/pEKwD6EKSGgLHDxaM9yA' rel='apple-touch-icon' type='image/png'>
# <link href='https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:320,height:345/https://www.filepicker.io/api/file/tkoAhgcsTyakndIvJlvn' rel='apple-touch-startup-image' type='image/png'>
# <link href='https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:640,height:690/https://www.filepicker.io/api/file/tkoAhgcsTyakndIvJlvn' rel='apple-touch-startup-image' type='image/png'>
# <meta name='apple-mobile-web-app-capable' content='yes' />
# <meta charset="UTF-8">
# <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="rqUvgeEgyNZDVnLrj5z7agImPEg53+rk+vlzyTRdkJ9hNxzsq54g2lXF4Y+XyiqgmDDijZaEJUk5Vd2n3TDjQA==" />
# <style type='text/css'>:root{--brand_primary: #252733;--brand_secondary: #252733;--brand_heading: #252733;--brand_text: #252733;--brand_navbar_text: #ffffff;--brand_navbar_fixed_text: #ffffff;--brand_homepage_heading: #ffffff;--brand_course_heading: #ffffff;--brand_video_player_color: #f6bc52;--font_family:SourceSansPro;} @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Black.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Black.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Black.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Black.ttf") format("truetype");
#   font-weight: 900;
#   font-style: normal;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-It.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-It.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-It.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-It.ttf") format("truetype");
#   font-weight: normal;
#   font-style: italic;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLightIt.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLightIt.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLightIt.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLightIt.ttf") format("truetype");
#   font-weight: 200;
#   font-style: italic;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-LightIt.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-LightIt.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-LightIt.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-LightIt.ttf") format("truetype");
#   font-weight: 300;
#   font-style: italic;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLight.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLight.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLight.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-ExtraLight.ttf") format("truetype");
#   font-weight: 200;
#   font-style: normal;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Semibold.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Semibold.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Semibold.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Semibold.ttf") format("truetype");
#   font-weight: 600;
#   font-style: normal;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Bold.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Bold.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Bold.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Bold.ttf") format("truetype");
#   font-weight: bold;
#   font-style: normal;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BoldIt.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BoldIt.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BoldIt.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BoldIt.ttf") format("truetype");
#   font-weight: bold;
#   font-style: italic;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Light.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Light.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Light.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Light.ttf") format("truetype");
#   font-weight: 300;
#   font-style: normal;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-SemiboldIt.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-SemiboldIt.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-SemiboldIt.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-SemiboldIt.ttf") format("truetype");
#   font-weight: 600;
#   font-style: italic;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Regular.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Regular.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Regular.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-Regular.ttf") format("truetype");
#   font-weight: normal;
#   font-style: normal;
#   font-display: swap; }
#
# @font-face {
#   font-family: 'SourceSansPro';
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BlackIt.eot");
#   src: url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BlackIt.eot?#iefix") format("embedded-opentype"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BlackIt.woff") format("woff"), url("//assets.teachablecdn.com/fonts/source-sans-pro/SourceSansPro-BlackIt.ttf") format("truetype");
#   font-weight: 900;
#   font-style: italic;
#   font-display: swap; }
# </style>
# <link rel="stylesheet" media="screen" href="https://fedora.teachablecdn.com/assets/pages-5014cb95044d3ba5d361e64e016c4696097bbf8c2bb8108f6af92b327f1d695f.css" />
# <style>/* Global Start */
# .rich-text h4 {
#     margin-bottom: 15px;
#     -webkit-hyphens: none;
#     -ms-hyphens: none;
#     hyphens: none;
# }
#
# .lde-ghost-button {
#     border: 2px solid #252733;
#     border-radius: 26px;
#     background: transparent;
#     font-style: normal;
#     font-weight: bold;
#     font-size: 16px;
#     line-height: 26px;
#     color: #252733;
# }
#
# .lde-ghost-button-white {
#     border: 2px solid #fff;
#     color: #fff;
# }
#
# .lde-color-yellow {
#     color: #F6BC52;
# }
#
# .lde-section-container {
#     width: 100%;
#     max-width: 1170px;
#     margin: 0 auto;
# }
#
# .lde-mobile, .lde-image-mobile {
#     display: none;
# }
#
# /* .lde-select__wrapper {
# } */
#
# .lde-select__wrapper label {
#     display: inline-block;
#     margin-bottom: 10px;
# }
#
# .lde-select {
#     margin-bottom: 30px;
#     position: relative;
# }
#
# .lde-select button {
#     border: 2px solid #fff;
#     box-sizing: border-box;
#     border-radius: 26px;
#     background: #36414D;
#     font-style: normal;
#     font-weight: bold;
#     font-size: 16px;
#     line-height: 26px;
#     color: #fff;
#     width: 100%;
#     height: 52px;
#     position: relative;
#     z-index: 1;
# }
#
# .lde-select button .lni-chevron-down {
#     position: absolute;
#     right: 15px;
#     font-size: 20px;
#     font-weight: 800;
#     top: 50%;
#     margin-top: -10px;
#     color: #F6BC52;
# }
#
# .lde-select .lde-select__options {
#     display: none;
#     position: absolute;
#     background: #fff;
#     color: #000;
#     width: 100%;
#     top: 50%;
#     padding: 25px 25px 0;
#     border-bottom-right-radius: 26px;
#     border-bottom-left-radius: 26px;
# }
#
# .lde-select .lde-select__options li {
#     padding: 0 !important;
#     cursor: pointer;
# }
#
# .lde-select button.lde-open {
#     display: block;
#     z-index: 4;
# }
#
# .lde-select button.lde-open + .lde-select__options {
#     display: block;
#     z-index: 3;
# }
#
# #lde-newsletter {
#     text-decoration-color: #252733;
# }
#
# #lde-newsletter span {
#     background: #F6BC52;
#     border-radius: 26px;
#     padding: 3px 20px;
#     color: #252733;
# }
#
# @media only screen and (max-width: 767px) {
#     .lde-desktop, .lde-image-desktop {
#         display: none;
#     }
#     .lde-mobile, .lde-image-mobile {
#         display: block;
#     }
# }
# /* Global End */
#
# /* Header start */
# .navbar__header {
#     padding: 25px 0;
#     max-width: 1170px;
# }
#
# .main::before {
#     content: '';
#     width: 100%;
#     height: 100px;
#     margin-bottom: -100px;
#     background: #252733;
# }
#
# .navbar__menu__list {
#     font-size: 16px;
#     font-weight: 700;
# }
#
# .hamburger:after,
# .hamburger:before {
#     content: '';
#     width: 30px;
# }
#
# .hamburger span,
# .hamburger:after {
#     margin-top: 8px;
#     width: 30px;
# }
#
# @media only screen and (max-width: 767px) {
#     .navbar__header {
#         padding: 10px 0;
#     }
# }
# /* Header end */
#
# /* Footer start */
# .footer__wrapper {
#     max-width: 1170px;
# }
#
# .footer__copyright,
# .footer__list.legal-links {
#     display: none;
# }
#
# .footer__list {
#     display: flex;
#     flex-wrap: wrap;
# }
#
# .footer__list li {
#     margin-right: 15px;
# }
#
# .footer__inner,
# .footer__inner a {
#     color: #F5F5F8;
# }
#
# .footer__inner:after {
#     content: '© Learn Data Engineering 2023';
# }
#
# @media only screen and (max-width: 767px) {
#     .footer__list {
#         justify-content: center;
#         margin-bottom: 15px;
#     }
#
#     .footer__list li:nth-child(3):before,
#     .footer__list li:nth-child(6):before {
#         content: '•';
#         margin-right: 12px;
#     }
# }
# /* Footer end */
#
# /* more info start */
# .b-lde-83118775-top {
#     padding-top: 40px;
# }
#
# .b-lde-83118775-bottom {
#     padding-bottom: 40px;
# }
#
# .b-lde-83118775-gutter_width {
#     --gutter-width: 30px;
# }
#
# .b-lde-83118775-content_width {
#     width: 100%;
#     max-width: 1170px;
# }
#
# .block__image-with-text .b-lde-83118775-text_color {
#     color: #36414D;
# }
#
# .block__image-with-text.b-lde-83118775-background_color {
#     background-color: #F5F5F8;
# }
#
# .block__image-with-text .b-lde-83118775-heading_color .block__image-with-text__inner__heading {
#     color: #36414D;
# }
#
# .block__image-with-text .b-lde-83118775-text_alignment {
#     text-align: left;
# }
#
# .block__image-with-text__image.b-lde-83118775-image_border_radius {
#     border-radius: 0px;
# }
#
# #block-lde-83118775 .block__image-with-text__wrapper {
#     align-items: flex-start;
# }
#
# #block-lde-83118775 .block__image-with-text__image {
#     width: 170px;
#     margin-right: 30px;
# }
#
# #block-lde-83118775 .block__image-with-text__text-wrapper {
#     width: calc(100% - 200px);
#     margin-left: 0;
# }
#
# @media screen and (min-width: 768px) {
#     .b-lde-83118775-top {
#         padding-top: 70px;
#     }
#
#     .b-lde-83118775-bottom {
#         padding-bottom: 70px;
#     }
#
#     .b-lde-83118775-gutter_width .block__image-with-text__text-wrapper {
#         width: calc(100% - 185px);
#         margin-left: 15px;
#     }
#
#     .b-lde-83118775-gutter_width div.block__image-with-text__image {
#         width: 185px;
#         margin-right: 15px;
#     }
# }
#
# @media screen and (max-width: 767px) {
#     #block-lde-83118775 .block__image-with-text {
#         position: relative;
#         margin-top: 110px;
#     }
#
#     #block-lde-83118775 .block__image-with-text__image {
#         width: 110px;
#         margin-right: 0;
#         position: absolute;
#         left: 50%;
#         margin-left: -55px;
#         top: -27px;
#     }
#
#     #block-lde-83118775 .block__image-with-text__inner__heading h4 {
#         font-size: 20px;
#         line-height: 24px;
#     }
#
#     #block-lde-83118775 .block__image-with-text__text-wrapper {
#         text-align: center;
#         width: 100%;
#         padding-left: 0;
#         padding-right: 0;
#         padding-bottom: 0;
#     }
#
#     #block-lde-83118775 .lde-ghost-button {
#         width: 100%;
#         max-width: 330px;
#     }
# }
# /* more info end */
#
# /* sign up start */
# #lde-sign-up-wrapper {
#     color: #fff;
#     background: #252733;
#     font-size: 16px;
#     border-bottom: 1px solid #fff;
#     overflow: hidden;
# }
#
# #lde-sign-up-wrapper .lde-section-container {
#     display: flex;
#     justify-content: space-between;
#     position: relative;
# }
# #lde-sign-up-wrapper .lde-section-container:after {
#     content:'';
#     height: 100%;
#     background: #36414D;
#     position: absolute;
#     width: 100%;
#     right: -100%;
#     top:0;
# }
#
# #lde-sign-up-wrapper .lde-sign-up-text,
# #lde-sign-up-wrapper .lde-sign-up-cta {
#     padding: 50px 0;
# }
#
# #lde-sign-up-wrapper h5 {
#     font-size: 24px;
#     margin-bottom: 10px;
#     line-height: 34px;
# }
#
# #lde-sign-up-wrapper .lde-sign-up-text {
#     font-weight: 700;
#     line-height: 26px;
# }
#
# #lde-sign-up-wrapper .lde-sign-up-cta {
#     position: relative;
# }
#
# #lde-sign-up-wrapper .lde-sign-up-cta:before,
# #lde-sign-up-wrapper .lde-sign-up-cta:after {
#     width: 30px;
#     height: 50%;
#     position: absolute;
#     left: 0;
#     content: "";
# }
#
# #lde-sign-up-wrapper .lde-sign-up-cta:before {
#     top: 0px;
#     background: linear-gradient(to right top, #252733 50%, transparent 50%);
# }
#
# #lde-sign-up-wrapper .lde-sign-up-cta:after {
#     top: 50%;
#     background: linear-gradient(to right bottom, #252733 50%, transparent 50%)
# }
#
# #lde-sign-up-wrapper .lde-sign-up-cta {
#     padding-left: 80px;
#     background: #36414D;
# }
#
# #lde-sign-up-wrapper .lde-ghost-button {
#     min-width: 370px;
# }
#
# @media screen and (max-width: 767px) {
#     #lde-sign-up-wrapper .lde-section-container {
#         flex-direction: column;
#         text-align: center;
#     }
#
#     #lde-sign-up-wrapper .lde-sign-up-cta:before,
#     #lde-sign-up-wrapper .lde-sign-up-cta:after {
#         width: 50%;
#         height: 30px;
#         position: absolute;
#         top: 0;
#         content: "";
#     }
#
#     #lde-sign-up-wrapper .lde-sign-up-cta:before {
#         left: 0;
#         background: linear-gradient(to left bottom, #252733 50%, transparent 50%);
#     }
#
#     #lde-sign-up-wrapper .lde-sign-up-cta:after {
#         left: 50%;
#         background: linear-gradient(to right bottom, #252733 50%, transparent 50%);
#     }
#
#     #lde-sign-up-wrapper .lde-sign-up-cta {
#         padding: 60px 15px 40px;
#     }
#
#     #lde-sign-up-wrapper .lde-section-container:after {
#         display: none;
#     }
#
#     #lde-sign-up-wrapper .lde-ghost-button {
#         min-width: 330px;
#     }
# }
# /* sign up End */
#
# /* Banner Start */
# section.banner {
#     max-width: 1170px;
#     margin: 0 auto;
# }
#
# div.banner__inner {
#     min-height: 400px;
#     padding-bottom: 0;
# }
#
# div.banner .header {
#     margin-bottom: 10px;
# }
#
# div.banner .header h1 {
#     font-size: 38px;
#     line-height: 48px;
# }
#
# div.banner__inner .subheader h2 {
#     font-size: 24px;
#     line-height: 34px;
# }
#
# @media only screen and (max-width: 767px) {
#     div.banner__inner {
#         min-height: 260px;
#     }
#
#     div.banner div.banner__inner h1 {
#         font-size: 28px;
#         line-height: 35px;
#     }
#
#     div.banner div.banner__inner .subheader h2 {
#         font-size: 20px;
#         line-height: 24px;
#     }
# }
# /* Banner End */
#
# /* USPs Start */
# div.block-custom-name-usps .block__column {
#     max-width: 320px;
# }
#
# div.block-custom-name-usps .block__text-with-image-grid__column__image {
#     height: 70px;
#     margin: 0 auto;
# }
#
# div.block-custom-name-usps .block__text-with-image-grid__column__heading-text {
#     margin-top: 8px;
# }
#
# div.block-custom-name-usps .block__text-with-image-grid__column__body {
#     margin-top: 0;
#     font-size: 14px;
# }
#
# @media only screen and (max-width: 767px) {
#     div.block-custom-name-usps .block__column {
#         margin: 0 auto 30px;
#         min-height: 70px;
#         text-align: left;
#     }
#
#     div.block-custom-name-usps .block__text-with-image-grid__column__image {
#         width: auto;
#         float: left;
#         margin-right: 15px;
#     }
# }
# /* USPs End */
#
# /* Salary Start */
# @media only screen and (max-width: 767px) {
#     .block-custom-name-grow-your-salary-text .container {
#         padding-top: 40px;
#         padding-bottom: 40px;
#     }
# }
# /* Salary End */
#
# /* My students Start */
# .block-custom-name-my-students .block__text-with-image-grid__column__image {
#     height: 230px;
#     width: auto;
#     margin: 0 auto;
# }
#
# .block-custom-name-my-students .block__text-with-image-grid__column__body em {
#     font-size: 14px;
#     line-height: 20px;
# }
#
# @media only screen and (max-width: 767px) {
#     .block-custom-name-my-students .block__column {
#         padding-left: 86px;
#         position: relative;
#         text-align: left;
#         max-width: 330px;
#         width: 100%;
#         margin: 0 auto 24px;
#     }
#
#     .block-custom-name-my-students .block__text-with-image-grid__column__image {
#         height: auto;
#         width: 72px;
#         margin: 0;
#         position: absolute;
#         left: 0;
#         top: 0;
#     }
#
#     .block-custom-name-my-students h5 {
#         font-size: 20px;
#         line-height: 24px;
#         margin: 0;
#     }
#
#     .block-custom-name-my-students h5 + p {
#         font-size: 14px;
#         line-height: 20px;
#         margin: 0;
#     }
#
#     .block-custom-name-my-students .block__text-with-image-grid__column__body {
#         margin-top: 5px;
#     }
# }
# /* My students End */</style>
# <title>All Data Engineering Courses | Learn Data Engineering</title>
# <link rel="canonical" href="https://learndataengineering.com/p/all-courses">
# <meta property="og:image" content="https://file-uploads.teachablecdn.com/a84d6072c63744fea8454bbecc0258e1/f1da6f14f1c1429e9f910a09d7ab446b">
# <meta property="og:title" content="All Data Engineering Courses">
# <meta property="og:type" content="website">
# <meta property="og:url" content="https://learndataengineering.com/p/all-courses">
# <meta name="brand_video_player_color" content="#f6bc52">
# <meta name="site_title" content="Learn Data Engineering">
# <script src='//fast.wistia.com/assets/external/E-v1.js'></script>
# <script src='https://www.recaptcha.net/recaptcha/api.js' async defer></script>
# <meta name="asset_host" content="https://fedora.teachablecdn.com">
# <script src="https://fedora.teachablecdn.com/packs/pages--adbf6cbef494a2fc429f.js"></script>
# <meta id='iris-url' data-iris-url=https://eventable.teachable.cloud />
# <script type="text/javascript">
#   window.heap=window.heap||[],heap.load=function(e,t){window.heap.appid=e,window.heap.config=t=t||{};var r=document.createElement("script");r.type="text/javascript",r.async=!0,r.src="https://cdn.heapanalytics.com/js/heap-"+e+".js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(r,a);for(var n=function(e){return function(){heap.push([e].concat(Array.prototype.slice.call(arguments,0)))}},p=["addEventProperties","addUserProperties","clearEventProperties","identify","resetIdentity","removeEventProperty","setEventProperties","track","unsetEventProperty"],o=0;o<p.length;o++)heap[p[o]]=n(p[o])},heap.load("318805607");
#   window.heapShouldTrackUser = true;
# </script>
# <script type="text/javascript">
#   var _user_id = ''; // Set to the user's ID, username, or email address, or '' if not yet known.
#   var _session_id = '2a7eb549580c8904fea2b694a132855a'; // Set to a unique session ID for the visitor's current browsing session.
#
#   var _sift = window._sift = window._sift || [];
#   _sift.push(['_setAccount', '2e541754ec']);
#   _sift.push(['_setUserId', _user_id]);
#   _sift.push(['_setSessionId', _session_id]);
#   _sift.push(['_trackPageview']);
#
#   (function() {
#     function ls() {
#       var e = document.createElement('script');
#       e.src = 'https://cdn.sift.com/s.js';
#       document.body.appendChild(e);
#     }
#     if (window.attachEvent) {
#       window.attachEvent('onload', ls);
#     } else {
#       window.addEventListener('load', ls, false);
#     }
#   })();
# </script>
# <script id="Cookiebot" src="https://consent.cookiebot.com/uc.js" data-cbid="5b683cb3-a69a-462d-9f10-8e10ef3e3fa2" data-blockingmode="auto" type="text/javascript"></script>
# <link rel="stylesheet" href="https://cdn.lineicons.com/3.0/lineicons.css">
# <script>
#     (function() {
#         function poll(fn, callback) {
#             var endTime = Number(new Date()) + (30000),
#                 interval = 42;
#
#             (function p() {
#                 if (fn()) {
#                     callback(fn());
#                 } else if (Number(new Date()) < endTime) {
#                     setTimeout(p, interval);
#                 }
#             })();
#         }
#
#         poll(function() {
#             return document.querySelector('#hamburger-menu');
#         }, function(navi) {
#             var listItems = navi.querySelectorAll('li:not(.inner-menu li)'),
#                 target = listItems[(listItems.length - 1)];
#
#             if(document.querySelector('#user-menu')) {
#                 target = target.previousElementSibling;
#             }
#
#             target.insertAdjacentHTML('afterend', ''+
#                 '<li><a id="lde-newsletter" href="https://hello.learndataengineering.com/subscribe-de-news" target="_blank"><span>Newsletter</span></a></li>'
#             );
#         });
#
#     })();
# </script>
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-10950946676"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'AW-10950946676');
# </script>
#
# <script type="text/javascript" src="//widget.trustpilot.com/bootstrap/v5/tp.widget.bootstrap.min.js" async></script>
#
# <script>
#   if(typeof ga != 'function') {
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   }
#   ga('create', 'UA-44397410-1', 'auto', {'name': 'fedoraTracker', 'allowLinker': true});
#   ga('fedoraTracker.set', 'anonymizeIp', true);
#   ga('fedoraTracker.require', 'linker');
#   ga('fedoraTracker.linker:autoLink', ['learndataengineering.com',  'sso.teachable.com'], false, true );
#   ga('fedoraTracker.require', 'ecommerce');
#   ga('fedoraTracker.require', 'ec');
#   ga('fedoraTracker.send', 'pageview');
#   ga('create', 'UA-44397410-4', 'auto', {'name': 'teachableTracker', 'allowLinker': true});
#   ga('teachableTracker.set', 'anonymizeIp', true);
#   ga('teachableTracker.require', 'linker');
#   ga('teachableTracker.linker:autoLink', ['learndataengineering.com', 'sso.teachable.com'], false, true );
#   ga('teachableTracker.require', 'ecommerce');
#   ga('teachableTracker.require', 'ec');
#   ga('teachableTracker.send', 'pageview');
# </script>
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# </head>
# <body class="revamped_lecture_player">
# <meta http-content='IE=Edge' http-equiv='X-UA-Compatible'>
# <meta content='width=device-width,initial-scale=1.0' name='viewport'>
# <meta id="fedora-keys" data-commit-sha="f7be8855f1e006a634b8d2dfa4530e7ab86475c2" data-env="production" data-sentry-public-dsn="https://8149a85a83fa4ec69640c43ddd69017d@sentry.io/120346" data-stripe="pk_live_hkgvgSBxG4TAl3zGlXiB1KUX" data-track-all-ahoy="false" data-track-changes-ahoy="false" data-track-clicks-ahoy="false" data-track-sumbits-ahoy="false" data-filepicker="ADNupMnWyR7kCWRvm76Laz" data-iris-url="https://eventable.teachable.cloud" /><meta id="fedora-data" data-report-card="{}" data-course-ids="[]" data-completed-lecture-ids="[]" data-school-id="563816" data-school-launched="true" data-preview="logged_out" data-turn-off-fedora-branding="true" data-plan-supports-whitelabeling="true" data-powered-by-text="Powered by" data-asset-path="//https://fedora.teachablecdn.com/assets/footer/teachable-logomark-white-31d2296978598bacace50e6d48a2e1223c20a9b074af424acdd465676f81560f.svg" data-school-preferences="{&quot;ssl_forced&quot;:&quot;true&quot;,&quot;anonymize_ips&quot;:&quot;true&quot;,&quot;paypal_enabled&quot;:&quot;true&quot;,&quot;autoplay_lectures&quot;:&quot;true&quot;,&quot;comments_threaded&quot;:&quot;true&quot;,&quot;course_blocks_beta&quot;:&quot;true&quot;,&quot;eu_vat_tax_enabled&quot;:&quot;false&quot;,&quot;legacy_back_office&quot;:&quot;false&quot;,&quot;themeable_disabled&quot;:&quot;false&quot;,&quot;back_office_enabled&quot;:&quot;true&quot;,&quot;comments_moderation&quot;:&quot;false&quot;,&quot;eu_vat_tax_eligible&quot;:&quot;true&quot;,&quot;charge_exclusive_tax&quot;:&quot;true&quot;,&quot;send_receipts_emails&quot;:&quot;true&quot;,&quot;autocomplete_lectures&quot;:&quot;false&quot;,&quot;class_periods_enabled&quot;:&quot;false&quot;,&quot;tax_inclusive_pricing&quot;:&quot;false&quot;,&quot;authors_can_manage_pbc&quot;:&quot;true&quot;,&quot;css_properties_enabled&quot;:&quot;false&quot;,&quot;preenrollments_enabled&quot;:&quot;false&quot;,&quot;new_text_editor_enabled&quot;:&quot;true&quot;,&quot;require_terms_agreement&quot;:&quot;true&quot;,&quot;send_new_comment_emails&quot;:&quot;false&quot;,&quot;send_drip_content_emails&quot;:&quot;true&quot;,&quot;ssl_forced_from_creation&quot;:&quot;true&quot;,&quot;turn_off_fedora_branding&quot;:&quot;true&quot;,&quot;allow_comment_attachments&quot;:&quot;true&quot;,&quot;authors_can_email_students&quot;:&quot;false&quot;,&quot;authors_can_manage_coupons&quot;:&quot;false&quot;,&quot;custom_email_limit_applied&quot;:&quot;false&quot;,&quot;teachable_accounts_enabled&quot;:&quot;true&quot;,&quot;teachable_payments_enabled&quot;:&quot;true&quot;,&quot;authors_can_import_students&quot;:&quot;false&quot;,&quot;authors_can_publish_courses&quot;:&quot;false&quot;,&quot;internal_subscriptions_beta&quot;:&quot;true&quot;,&quot;recaptcha_enabled_on_signup&quot;:&quot;true&quot;,&quot;display_vat_inclusive_prices&quot;:&quot;true&quot;,&quot;single_page_checkout_enabled&quot;:&quot;true&quot;,&quot;authors_can_set_course_prices&quot;:&quot;false&quot;,&quot;send_lead_confirmation_emails&quot;:&quot;true&quot;,&quot;affiliate_cookie_duration_days&quot;:&quot;365&quot;,&quot;authors_can_issue_certificates&quot;:&quot;false&quot;,&quot;store_student_cards_separately&quot;:&quot;true&quot;,&quot;authors_can_manage_certificates&quot;:&quot;false&quot;,&quot;authors_can_manage_course_pages&quot;:&quot;false&quot;,&quot;disable_js_course_event_tracking&quot;:&quot;false&quot;,&quot;exclusive_vat_on_custom_gateways&quot;:&quot;true&quot;,&quot;is_edit_site_onboarding_complete&quot;:&quot;false&quot;,&quot;send_certificate_issuance_emails&quot;:&quot;true&quot;,&quot;owner_teachable_accounts_required&quot;:&quot;true&quot;,&quot;prevent_payment_plan_cancellation&quot;:&quot;true&quot;,&quot;send_subscription_reminder_emails&quot;:&quot;true&quot;,&quot;automatically_add_disqus_attachments&quot;:&quot;true&quot;,&quot;recalc_course_pct_on_lecture_publish&quot;:&quot;true&quot;,&quot;send_confirmation_instructions_emails&quot;:&quot;true&quot;,&quot;send_limited_time_unenroll ...
# <div class="root" onclick="offMenu(event)">
#
#
# <a id="top"></a>
# <style id="ncs">
#   :root {
#
#     --header_width: 960px;
#   }
# </style>
# <header id="header" class="header header-sticky">
#
# <nav class="navbar is-not-signed-in navbar-course-hero  at-top" id='navbar' role='navigation'>
# <div class='navbar__header'>
#
# <a class='navbar__header__logolink' href='https://learndataengineering.com'>
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=height:60/https://www.filepicker.io/api/file/kGHvtD8jSFedYpQpSfhw" alt="Learn Data Engineering" srcset="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=height:120/https://www.filepicker.io/api/file/kGHvtD8jSFedYpQpSfhw 2x" />
# </a>
#
# <div class="navbar__menu">
# <button for="f-toggle" tabindex="0" role="button" id="hamburger" class="hamburger" aria-label="Toggle navigation" onclick="toggleMenu('hamburger-menu')">
# <span></span>
# </button>
# <ul class='navbar__menu__list menu hidden' id="hamburger-menu" role="menu" aria-describedby="hamburger" tabindex="0">
# <li>
# <a href='/p/academy' target=''>
# Academy
# </a>
# </li>
# <li>
# <a href='https://learndataengineering.com/p/all-courses' target=''>
# All Courses
# </a>
# </li>
#
# <li>
# <a href='/sign_in'>
# Login
# </a>
# </li>
# <li>
# <a href='/sign_up'>
# Sign Up
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <main class='view-school page-layout-v2 main'>
# <div id="blocks" data-ss-school-id='563816' class="blocks-page blocks-page-course_sales_page_v2 ">
#
#
#
# <style type='text/css'>.b-124815737-top { padding-top: 11.200000000000001px; } .b-124815737-bottom { padding-bottom: 11.200000000000001px; } .b-124815737-text_color { color: #36414D; } .b-124815737-content_width { max-width: 590px; } .b-124815737-background_color { background-color: #ffffff; } .b-124815737-heading_text_color { color: #36414D; }</style>
# <div class="course-block block text block-custom-name-overview-headline " id="block-124815737">
# <style>
#
#   .block__text .b-124815737-text_color {
#     color: #36414D
#   }
#
#
#
#   .block__text .b-124815737-content_width {
#     width: 590px;
#   }
#
#
#
#   .block__text .b-124815737-heading_text_color h1,
#   .block__text .b-124815737-heading_text_color h2,
#   .block__text .b-124815737-heading_text_color h3,
#   .block__text .b-124815737-heading_text_color h4,
#   .block__text .b-124815737-heading_text_color h5,
#   .block__text .b-124815737-heading_text_color h6 {
#     color: #36414D
#   }
#
#
#   .block__text .block__text-wrapper h2{
#     margin-bottom: 2px;
#   }
#
#   .block__text .block__text-wrapper h3{
#     margin-bottom: 5px;
#   }
#
#   .block__text .block__text-wrapper h4{
#     margin-bottom: 9px;
#   }
#
#   .block__text .block__text-wrapper h5{
#     margin-bottom: 11px;
#   }
#
#   .block__text .block__text-wrapper h6{
#     margin-bottom: 14px;
#   }
#
# @media screen and (min-width: 768px) {
#   .b-124815737-top {
#     padding-top: 20px;
#   }
#   .b-124815737-bottom {
#     padding-bottom: 20px;
#   }
# }
# </style>
# <section class='container bl block__text rich-text b-124815737-top b-124815737-bottom b-124815737-background_color'>
# <div class="block__text-wrapper b-124815737-content_width b-124815737-heading_text_color b-124815737-text_color" data-target="block.data.body">
# <h3 class="ql-align-center"><strong>Explore each individual topic</strong></h3><p class="ql-align-center">Click on each individual topic below to view the introduction video, read the complete syllabus and see a list of all the lessons.<br class="softbreak"></p>
# </div>
# </section>
# </div>
#
# <style type='text/css'>.b-124815738-top { padding-top: 22.400000000000002px; } .b-124815738-bottom { padding-bottom: 22.400000000000002px; } .b-124815738-card_style { --card_style: grid; } .b-124815738-gutter_width { --gutter-width: 24px; } .b-124815738-content_width { max-width: 960px; } .b-124815738-heading_color { color: #36414D; } .b-124815738-background_color { background-color: #F5F5F8; } .b-124815738-card_border_color { border-color: #000000; } .b-124815738-card_border_width { border-width: 0px; } .b-124815738-card_border_radius { border-radius: 0px; } .b-124815738-card_text_alignment { text-align: center; } .b-124815738-button_border_radius { border-radius: 0px; } .b-124815738-card_background_color { background-color: #FFFFFF; }</style>
# <div class="course-block block featured_products  " id="block-124815738">
# <style>
#   .block__featured-products__heading_text.b-124815738-heading_color {
#     color: #36414D;
#   }
#   .block__featured-products.b-124815738-background_color {
#     background-color: #F5F5F8;
#   }
#   .block__featured-products .b-124815738-card_border_color,
#   .block__featured-products .b-124815738-card_border_width {
#     border: 0px solid #000000;
#   }
#   .block__featured-products .b-124815738-card_text_alignment .featured-product-card__content__title,
#   .block__featured-products .b-124815738-card_text_alignment .course-card__content__subtitle {
#     text-align: center;
#   }
#   .featured-product-card.b-124815738-card_background_color {
#     background-color: #FFFFFF;
#   }
#   .block__featured-products__button .b-124815738-button_border_radius {
#     border-radius: 0px;
#   }
#   @media screen and (min-width: 768px) {
#     .b-124815738-top {
#       padding-top: 40px;
#     }
#     .b-124815738-bottom {
#       padding-bottom: 40px;
#     }
#
#     .b-124815738-gutter_width .block__columns, .b-124815738-gutter_width .block__columns__fixed {
#         grid-column-gap: 24px;
#     }
#
#   }
# </style>
# <section class="bl block__featured-products block__featured-products__cards block__columns-per-row--3 b-124815738-top b-124815738-bottom b-124815738-gutter_width b-124815738-background_color">
# <div class="block__featured-products__heading_text b-124815738-heading_color rich-text"><h3>
# <strong> 1. Data Engineering Basics</strong><br class="softbreak">
# </h3></div>
# <div class="block__columns b-124815738-content_width">
#
# <div data-featured-product-type="Course" data-featured-product-id="1296272" class="featured-product-card card-style-grid block__column b-124815738-card_background_color b-124815738-card_border_color b-124815738-card_border_width b-124815738-card_border_radius b-124815738-card_text_alignment">
# <a href="/p/introduction-to-data-engineering">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://www.filepicker.io/api/file/ywld6ui0TFCyBRIa7WlK" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Introduction to Data Engineering">
# Introduction to Data Engineering
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1296272" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Introduction to Data Engineering with over 1 hour of videos including my journey here.">
# Introduction to Data Engineering with over 1 hour of videos including my journey here.
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1296272" data-featured-product-id="1296272">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
#
# <div data-featured-product-type="Course" data-featured-product-id="1296125" class="featured-product-card card-style-grid block__column b-124815738-card_background_color b-124815738-card_border_color b-124815738-card_border_width b-124815738-card_border_radius b-124815738-card_text_alignment">
# <a href="/p/data-engineering-fundamentals">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://cdn.filestackcontent.com/H5Em6KaCT56m3sXEamgP" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Computer Science Fundamentals">
# Computer Science Fundamentals
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1296125" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="A complete guide of topics and resources you should know as a Data Engineer.">
# A complete guide of topics and resources you should know as a Data Engineer.
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1296125" data-featured-product-id="1296125">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
#
# <div data-featured-product-type="Course" data-featured-product-id="1306106" class="featured-product-card card-style-grid block__column b-124815738-card_background_color b-124815738-card_border_color b-124815738-card_border_width b-124815738-card_border_radius b-124815738-card_text_alignment">
# <a href="/p/introduction-to-python">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://www.filepicker.io/api/file/0T5Z8HgLT2S8o2KeTQI4" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Introduction to Python">
# Introduction to Python
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1306106" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Learn all the fundamentals of Python to start coding quick">
# Learn all the fundamentals of Python to start coding quick
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://fedora.teachablecdn.com/assets/user-0ae68ba67e6ead32c4ff1cc668d501f896bddd5ef1667ac3e9ff29ce601ed653.png" alt="Amit Jain" />
# <p class="featured-product-card__author__name" title="Amit Jain">
# Amit Jain
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1306106" data-featured-product-id="1306106">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
#
# <div data-featured-product-type="Course" data-featured-product-id="1633007" class="featured-product-card card-style-grid block__column b-124815738-card_background_color b-124815738-card_border_color b-124815738-card_border_width b-124815738-card_border_radius b-124815738-card_text_alignment">
# <a href="/p/python-for-data-engineers">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://file-uploads.teachablecdn.com/77c0b1ccf82c4225abcd1622cba072e1/ffa2ceee29da4cc3a6b7bfa1d1230e2e" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Python for Data Engineers">
# Python for Data Engineers
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1633007" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Learn all the Python topics a Data Engineer needs even if you don&#39;t have a coding background">
# Learn all the Python topics a Data Engineer needs even if you don&#39;t have a coding background
# </h4>
# <div class="featured-product-card__meta">
#
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1633007" data-featured-product-id="1633007">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
#
# <div data-featured-product-type="Course" data-featured-product-id="1692087" class="featured-product-card card-style-grid block__column b-124815738-card_background_color b-124815738-card_border_color b-124815738-card_border_width b-124815738-card_border_radius b-124815738-card_text_alignment">
# <a href="/p/docker-fundamentals">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://file-uploads.teachablecdn.com/eaca97684333480c88f50b10f49845e1/dfa1943a1451409ab2eae97722f058aa" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Docker Fundamentals">
# Docker Fundamentals
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1692087" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Learn all the fundamental Docker concepts with hands-on examples">
# Learn all the fundamental Docker concepts with hands-on examples
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1692087" data-featured-product-id="1692087">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
# </div>
# </section>
# </div>
#
# <style type='text/css'>.b-124815739-top { padding-top: 22.400000000000002px; } .b-124815739-bottom { padding-bottom: 22.400000000000002px; } .b-124815739-card_style { --card_style: grid; } .b-124815739-gutter_width { --gutter-width: 24px; } .b-124815739-content_width { max-width: 960px; } .b-124815739-heading_color { color: #36414D; } .b-124815739-background_color { background-color: #F5F5F8; } .b-124815739-card_border_color { border-color: #000000; } .b-124815739-card_border_width { border-width: 0px; } .b-124815739-card_border_radius { border-radius: 0px; } .b-124815739-card_text_alignment { text-align: center; } .b-124815739-button_border_radius { border-radius: 0px; } .b-124815739-card_background_color { background-color: #FFFFFF; }</style>
# <div class="course-block block featured_products  " id="block-124815739">
# <style>
#   .block__featured-products__heading_text.b-124815739-heading_color {
#     color: #36414D;
#   }
#   .block__featured-products.b-124815739-background_color {
#     background-color: #F5F5F8;
#   }
#   .block__featured-products .b-124815739-card_border_color,
#   .block__featured-products .b-124815739-card_border_width {
#     border: 0px solid #000000;
#   }
#   .block__featured-products .b-124815739-card_text_alignment .featured-product-card__content__title,
#   .block__featured-products .b-124815739-card_text_alignment .course-card__content__subtitle {
#     text-align: center;
#   }
#   .featured-product-card.b-124815739-card_background_color {
#     background-color: #FFFFFF;
#   }
#   .block__featured-products__button .b-124815739-button_border_radius {
#     border-radius: 0px;
#   }
#   @media screen and (min-width: 768px) {
#     .b-124815739-top {
#       padding-top: 40px;
#     }
#     .b-124815739-bottom {
#       padding-bottom: 40px;
#     }
#
#     .b-124815739-gutter_width .block__columns, .b-124815739-gutter_width .block__columns__fixed {
#         grid-column-gap: 24px;
#     }
#
#   }
# </style>
# <section class="bl block__featured-products block__featured-products__cards block__columns-per-row--3 b-124815739-top b-124815739-bottom b-124815739-gutter_width b-124815739-background_color">
# <div class="block__featured-products__heading_text b-124815739-heading_color rich-text"><h3>
# <strong>2. Platform &amp; Pipeline Design Fundamentals</strong><br class="softbreak">
# </h3></div>
# <div class="block__columns b-124815739-content_width">
#
# <div data-featured-product-type="Course" data-featured-product-id="1296282" class="featured-product-card card-style-grid block__column b-124815739-card_background_color b-124815739-card_border_color b-124815739-card_border_width b-124815739-card_border_radius b-124815739-card_text_alignment">
# <a href="/p/data-pipeline-design">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://www.filepicker.io/api/file/IJwlWcqQoOhfR770ptG0" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Data Platform And Pipeline Design">
# Data Platform And Pipeline Design
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1296282" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Learn how to build data pipelines with templates and examples for Azure, GCP and Hadoop.">
# Learn how to build data pipelines with templates and examples for Azure, GCP and Hadoop.
#
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
#
# ...
# <a href="/p/document-streaming">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://file-uploads.teachablecdn.com/f6c7c6d14dc244c7ab9214895c8fbce1/87607b6248ea4ed3be2f7c5a733c2420" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Document Streaming Project">
# Document Streaming Project
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1490617" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Document Streaming with FastAPI, Kafka, Spark Streaming, MongoDB and Streamlit">
# Document Streaming with FastAPI, Kafka, Spark Streaming, MongoDB and Streamlit
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1490617" data-featured-product-id="1490617">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
#
# <div data-featured-product-type="Course" data-featured-product-id="1551159" class="featured-product-card card-style-grid block__column b-124815741-card_background_color b-124815741-card_border_color b-124815741-card_border_width b-124815741-card_border_radius b-124815741-card_text_alignment">
# <a href="/p/time-series-influxdb-grafana">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://file-uploads.teachablecdn.com/926bf605ca6a497e8f6f9f67ed09ebe1/faa204d9bdee4ff3972a99b659c43637" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Storing &amp; Visualizing Time Series Data with InfluxDB and Grafana">
# Storing &amp; Visualizing Time Series Data with InfluxDB and Grafana
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1551159" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Learn how to use InfluxDB to store time series data and visualize interactive dashboards with Grafana">
# Learn how to use InfluxDB to store time series data and visualize interactive dashboards with Grafana
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1551159" data-featured-product-id="1551159">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
#
# <div data-featured-product-type="Course" data-featured-product-id="1382088" class="featured-product-card card-style-grid block__column b-124815741-card_background_color b-124815741-card_border_color b-124815741-card_border_width b-124815741-card_border_radius b-124815741-card_text_alignment">
# <a href="/p/data-engineering-with-hadoop">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://file-uploads.teachablecdn.com/13bf6b2330224ea7803c8d2bfed659e1/85c80fe4100d49b7ad9899f71e4de945" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Data Engineering with Hadoop">
# Data Engineering with Hadoop
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1382088" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Hadoop Project with HDFS, YARN, MapReduce, Hive and Sqoop!">
# Hadoop Project with HDFS, YARN, MapReduce, Hive and Sqoop!
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/9POWeJS6S867SDcilPms" alt="Suyog Nagaokar" />
# <p class="featured-product-card__author__name" title="Suyog Nagaokar">
# Suyog Nagaokar
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1382088" data-featured-product-id="1382088">
# %
# </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
# </div>
# </section>
# </div>
#
# <style type='text/css'>.b-124815742-top { padding-top: 22.400000000000002px; } .b-124815742-bottom { padding-bottom: 22.400000000000002px; } .b-124815742-card_style { --card_style: grid; } .b-124815742-gutter_width { --gutter-width: 24px; } .b-124815742-content_width { max-width: 960px; } .b-124815742-heading_color { color: #36414D; } .b-124815742-background_color { background-color: #F5F5F8; } .b-124815742-card_border_color { border-color: #000000; } .b-124815742-card_border_width { border-width: 0px; } .b-124815742-card_border_radius { border-radius: 0px; } .b-124815742-card_text_alignment { text-align: center; } .b-124815742-button_border_radius { border-radius: 0px; } .b-124815742-card_background_color { background-color: #FFFFFF; }</style>
# <div class="course-block block featured_products  " id="block-124815742">
# <style>
#   .block__featured-products__heading_text.b-124815742-heading_color {
#     color: #36414D;
#   }
#   .block__featured-products.b-124815742-background_color {
#     background-color: #F5F5F8;
#   }
#   .block__featured-products .b-124815742-card_border_color,
#   .block__featured-products .b-124815742-card_border_width {
#     border: 0px solid #000000;
#   }
#   .block__featured-products .b-124815742-card_text_alignment .featured-product-card__content__title,
#   .block__featured-products .b-124815742-card_text_alignment .course-card__content__subtitle {
#     text-align: center;
#   }
#   .featured-product-card.b-124815742-card_background_color {
#     background-color: #FFFFFF;
#   }
#   .block__featured-products__button .b-124815742-button_border_radius {
#     border-radius: 0px;
#   }
#   @media screen and (min-width: 768px) {
#     .b-124815742-top {
#       padding-top: 40px;
#     }
#     .b-124815742-bottom {
#       padding-bottom: 40px;
#     }
#
#     .b-124815742-gutter_width .block__columns, .b-124815742-gutter_width .block__columns__fixed {
#         grid-column-gap: 24px;
#     }
#
#   }
# </style>
# <section class="bl block__featured-products block__featured-products__cards block__columns-per-row--1 b-124815742-top b-124815742-bottom b-124815742-gutter_width b-124815742-background_color">
# <div class="block__featured-products__heading_text b-124815742-heading_color rich-text"><h3><strong>5. Certifications</strong></h3></div>
# <div class="block__columns__fixed b-124815742-content_width">
#
# <div data-featured-product-type="Course" data-featured-product-id="1654910" class="featured-product-card card-style-grid block__column b-124815742-card_background_color b-124815742-card_border_color b-124815742-card_border_width b-124815742-card_border_radius b-124815742-card_text_alignment">
# <a href="/p/associate-data-engineer-certificate">
#
# <div class="featured-product-card__image-container">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:705/https://file-uploads.teachablecdn.com/870da4ee39b84591b78505e797d94be1/dd84356e5cbf41699a37d8cca9690933" role="presentation" />
# </div>
# <div class="featured-product-card__content">
# <h3 class="featured-product-card__content__title" title="Associate Data Engineer">
# Associate Data Engineer
# </h3>
#
# <div aria-hidden="true" class="featured-product-card__progressbar hidden">
# <div role="progressbar" aria-valuemin="0" aria-valuemax="100" aria-labelledby="percent-complete-1654910" class="featured-product-card__progressbar-fill"></div>
# </div>
#
# <h4 class="featured-product-card__content__subtitle" title="Certify that you are job ready with the Associate Data Engineer exam">
# Certify that you are job ready with the Associate Data Engineer exam
# </h4>
# <div class="featured-product-card__meta">
#
#
# <div class="featured-product-card__meta__item featured-product-card__author">
# <img src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0" alt="Andreas Kretz" />
# <p class="featured-product-card__author__name" title="Andreas Kretz">
# Andreas Kretz
# </p>
# </div>
#
# <div class="featured-product-card__meta__item featured-product-card__progress hidden" aria-hidden="true">
# <span class="featured-product-card__percentage" id="percent-complete-1654910" data-featured-product-id="1654910">
# %
#  </span>
# COMPLETE
# </div>
#
# <p data-include-vat-price= class="featured-product-card__meta__item featured-product-card__price">
# </p>
# </div>
# </div>
# </a>
# </div>
# </div>
# </section>
# </div>
#
# <style type='text/css'>.b-124815743-top { padding-top: 22.400000000000002px; } .b-124815743-bottom { padding-bottom: 22.400000000000002px; } .b-124815743-background_color { background-color: #FFFFFF; } .b-124815743-button_border_radius { border-radius: 25px; }</style>
# <div class="course-block block button  " id="block-124815743">
# <style>
#
#   .block__button--button.b-124815743-button_border_radius {
#     border-radius: 25px;
#   }
#
#   @media screen and (min-width: 768px) {
#     .b-124815743-top {
#       padding-top: 40px;
#     }
#     .b-124815743-bottom {
#       padding-bottom: 40px;
#     }
#   }
# </style>
# <section class="container bl b-124815743-background_color b-124815743-bottom b-124815743-top">
# <div class="block__button">
# <a href='https://learndataengineering.com/p/academy' target="_blank" rel="noopener" class='block__button--link'>
# <button class='block__button--button b-124815743-button_border_radius base-button' data-target="block.data.button_text">
# Back to the Academy
# </button>
# </a>
# </div>
# </section>
# </div>
# </div>
# </main>
# <style id="footerStyles">
#   :root {
#     --footer_width: 960px;
#   }
# </style>
# <footer class=''>
# <div class="footer">
# <div class='footer__wrapper'>
# <div class='footer__inner'>
# <ul class="footer__list">
# <li class="footer__copyright">
# &copy;
# Learn Data Engineering
# 2023
# </li>
# <li>
# <a href='/p/legal-notice' target=''>
# Legal Notice
# </a>
# </li>
# <li>
# <a href='/p/use-of-cookies' target=''>
# Use of Cookies
# </a>
# </li>
# <li>
# <a href='/p/right-of-withdrawal' target=''>
# Right of withdrawal and withdrawal form
# </a>
# </li>
# <li>
# <a href='/p/privacy' target=''>
# Privacy Policy
# </a>
# </li>
# <li>
# <a href='/p/terms' target=''>
# Terms of Use
# </a>
# </li>
# </ul>
# <ul class="footer__list legal-links">
# <li>
# <a href="/p/terms">
# Terms of Use
# </a>
# </li>
# <li>
# <a href="/p/privacy">
# Privacy Policy
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       if (!Element.prototype.closest) {
#         Element.prototype.closest = function(s) {
#           let el = this;
#           do {
#             if (el.matches(s)) return el;
#             el = el.parentElement || el.parentNode;
#           } while (el !== null && el.nodeType === 1);
#           return null;
#         };
#       }
#       const offMenu = event => {
#       if (event.target.closest('.navbar__menu')) return
#       document
#         .querySelectorAll('.menu')
#         .forEach(item => {
#           item.classList.add('hidden')
#           item.setAttribute('aria-hidden', 'true')
#         })
#       }
#       const toggleMenu = id => {
#   const el = document.getElementById(id)
#   if (el.classList.contains('hidden')) {
#     document
#       .querySelectorAll('.inner-menu')
#       .forEach(item => {
#         item.classList.add('hidden')
#         item.setAttribute('aria-hidden', 'true')
#       })
#     el.classList.remove('hidden')
#     el.setAttribute('aria-hidden', 'false')
#   } else {
#     el.classList.add('hidden')
#     el.setAttribute('aria-hidden', 'true')
#   }
#   !el.classList.contains('hidden') && el.focus()
# }
#
#       // toggle open class for v2 preview bar dropdown menu
#       const v2Dropdown = document.getElementsByClassName('v2-dropdown')[0]
#       const v2DropdownTrigger = document.querySelector('.v2-dropdown .menu-trigger')
#       // if the preview bar dropdown exists, add event listener to toggle preview menu
#       if (!!v2Dropdown) {
#         v2DropdownTrigger.addEventListener('click', () => {
#           v2Dropdown.classList.toggle('open')
#         })
#       }
#
#       const domBody = document.body
#       const usingMouse = 'using-mouse'
#       domBody.addEventListener('mousedown', () => {
#         domBody.classList.add(usingMouse)
#       })
#       domBody.addEventListener('keydown', () => {
#         domBody.classList.remove(usingMouse)
#       })
#
#       const headerEl = document.querySelector('#navbar')
#       const topHook = document.querySelector('#top')
#       if (
#         "IntersectionObserver" in window
#       ) {
#         const observer = new IntersectionObserver(entries => {
#           if (entries[0].boundingClientRect.y < 0) {
#             headerEl.classList.remove('at-top')
#           } else {
#             headerEl.classList.add('at-top')
#           }
#         },{threshold: 1});
#         observer.observe(topHook)
#       }
#     </script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'7a3b8852edb42fca',m:'lEM_ZoM.fpHODO9lZQxbMrmG3SzaiYgow_EdD2eAMjo-1678115500-0-AalqSpy2gwtSMlGoxFfbrWnP54sV/NACJ24HWIr0oZyKcOmGrrYGIxEVywZOEzM+/KyHdZeg04pOTdPhwcyyv1NteeCbUh4XyZiicYVS+ymikiSAIG2NanEb7/VKGYxbWQ==',s:[0x1e4dba6cae,0x31997e6af0],u:'/cdn-cgi/challenge-platform/h/g'};var now=Date.now()/1000,offset=14400,ts=''+(Math.floor(now)-Math.floor(now%offset)),_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/h/g/scripts/alpha/invisible.js?ts='+ts,document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %% [markdown]
# ### Step 2: Use BeautifulSoup to remove HTML tags
# Use `"lxml"` rather than `"html5lib"`.
#
# Again, you may have to scroll down past the javascript and CSS in the output of the last cell in this section to see the text. **Alternatively,** you can run the following two lines right before running `soup.get_text()`:
#
# ```python
# for script in soup(["script", "style"]):
#     script.decompose()
# ```
# Read more about this [here](https://stackoverflow.com/questions/22799990/beatifulsoup4-get-text-still-has-javascript).

# %%
#soup = BeautifulSoup(r.text, "lxml")
soup = BeautifulSoup(r.content, 'html.parser')
#soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# All Data Engineering Courses | Learn Data Engineering
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Academy
#
#
#
#
# All Courses
#
#
#
#
# Login
#
#
#
#
# Sign Up
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Explore each individual topicClick on each individual topic below to view the introduction video, read the complete syllabus and see a list of all the lessons.
#
#
#
#
#
#
#
#
#  1. Data Engineering Basics
#
#
#
#
#
#
#
#
#
# Introduction to Data Engineering
#
#
#
#
#
# Introduction to Data Engineering with over 1 hour of videos including my journey here.
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Computer Science Fundamentals
#
#
#
#
#
# A complete guide of topics and resources you should know as a Data Engineer.
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Introduction to Python
#
#
#
#
#
# Learn all the fundamentals of Python to start coding quick
#
#
#
#
#
# Amit Jain
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Python for Data Engineers
#
#
#
#
#
# Learn all the Python topics a Data Engineer needs even if you don't have a coding background
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Docker Fundamentals
#
#
#
#
#
# Learn all the fundamental Docker concepts with hands-on examples
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2. Platform & Pipeline Design Fundamentals
#
#
#
#
#
#
#
#
#
# Data Platform And Pipeline Design
#
#
#
#
#
# Learn how to build data pipelines with templates and examples for Azure, GCP and Hadoop.
#
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Platform & Pipelines Security
#
#
#
#
#
# Learn the important security fundamentals for Data Engineering
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Choosing Data Stores
#
#
#
#
#
# Learn the different types of data stores and when to use which.
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schema Design Data Stores
#
#
#
#
#
# Learn to define schemas for SQL, NoSQL databases and Data Warehouses
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Modern Data Warehouses & Data Lakes
#
#
#
#
#
# How to integrate a Data Lake with a Data Warehouse and query data directly from files
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3. Fundamental Tools
#
#
#
#
#
#
#
#
#
# Building APIs with FastAPI
#
#
#
#
#
# Learn the fundamentals of designing, creating and deploying APIs with FastAPI and Docker
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Apache Kafka Fundamentals
#
#
#
#
#
# Learn the fundamentals of Apache Kafka
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Apache Spark Fundamentals
#
#
#
#
#
# Apache Spark quick start course in Python with Jupyter notebooks, DataFrames, SparkSQL and RDDs.
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
# $40
#
#
#
#
#
#
#
#
#
#
#
#
# Data Engineering on Databricks
#
#
#
#
#
# Everything you need to get started with Databricks. From setup to building ETL pipelines &amp; warehousing.
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MongoDB Fundamentals
#
#
#
#
#
# Learn how to use MongoDB
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log Analysis with Elasticsearch
#
#
#
#
#
# Learn how to use Elasticsearch to monitor and debug your pipelines through log indexing
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Airflow Workflow Orchestration
#
#
#
#
#
# Learn how to orchestrate your data pipelines with Apache Airflow
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Snowflake for Data Engineers
#
#
#
#
#
# Everything you need to get started with Snowflake
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4. Full Hands-On Example Projects
#
#
#
#
#
#
#
#
#
# Data Engineering on AWS
#
#
#
#
#
# Full 5 hours course with complete example project. Building stream and batch processing pipelines on AWS.
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Machine Learning & Containerization On AWS
#
#
#
#
#
# Build a app that analyzes the sentiment of tweets and visualizing them on a user interface hosted as container
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Data Engineering on Azure
#
#
#
#
#
# Ingest, Store, Process, Serve and Visualize Streams of Data by Building Streaming Data Pipelines in Azure.
#
#
#
#
#
# Kristijan Bakarić
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contact Tracing with Elasticsearch
#
#
#
#
#
# Track 100,000 users in San Francisco using Elasticsearch and an interactive Streamlit user interface
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Document Streaming Project
#
#
#
#
#
# Document Streaming with FastAPI, Kafka, Spark Streaming, MongoDB and Streamlit
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Storing & Visualizing Time Series Data with InfluxDB and Grafana
#
#
#
#
#
# Learn how to use InfluxDB to store time series data and visualize interactive dashboards with Grafana
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Data Engineering with Hadoop
#
#
#
#
#
# Hadoop Project with HDFS, YARN, MapReduce, Hive and Sqoop!
#
#
#
#
#
# Suyog Nagaokar
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5. Certifications
#
#
#
#
#
#
#
#
# Associate Data Engineer
#
#
#
#
#
# Certify that you are job ready with the Associate Data Engineer exam
#
#
#
#
#
# Andreas Kretz
#
#
#
#
# %
#
# COMPLETE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Back to the Academy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ©
# Learn Data Engineering
# 2023
#
#
#
# Legal Notice
#
#
#
#
# Use of Cookies
#
#
#
#
# Right of withdrawal and withdrawal form
#
#
#
#
# Privacy Policy
#
#
#
#
# Terms of Use
#
#
#
#
#
#
# Terms of Use
#
#
#
#
# Privacy Policy

# %% [markdown]
# ### Step 3: Find all course summaries
# Use the BeautifulSoup's `find_all` method to select based on tag type and class name. Just ike in the video, you can right click on the item, and click "Inspect" to view its html on a web page.

# %%
tags = {tag.name for tag in soup.find_all()}
tags
# Out:
# {'a',
#  'body',
#  'br',
#  'button',
#  'div',
#  'footer',
#  'h3',
#  'h4',
#  'head',
#  'header',
#  'html',
#  'img',
#  'li',
#  'link',
#  'main',
#  'meta',
#  'nav',
#  'p',
#  'script',
#  'section',
#  'span',
#  'strong',
#  'style',
#  'title',
#  'ul'}

# %%
# class list set
class_list = set()
  
# iterate all tags
for tag in tags:
    if tag == "div":
        # find all element of tag
        for i in soup.find_all( tag ):

            # if tag has attribute of class
            if i.has_attr( "class" ):

                if len( i['class'] ) != 0:
                    class_list.add(" ".join( i['class']))

print(class_list)
# Out:
# {'featured-product-card__meta', 'course-block block text block-custom-name-overview-headline', 'featured-product-card__progressbar hidden', 'block__featured-products__heading_text b-124815742-heading_color rich-text', 'course-block block button', 'block__columns b-124815741-content_width', 'featured-product-card__image-container', 'footer', 'featured-product-card card-style-grid block__column b-124815741-card_background_color b-124815741-card_border_color b-124815741-card_border_width b-124815741-card_border_radius b-124815741-card_text_alignment', 'root', 'featured-product-card card-style-grid block__column b-124815742-card_background_color b-124815742-card_border_color b-124815742-card_border_width b-124815742-card_border_radius b-124815742-card_text_alignment', 'featured-product-card__content', 'blocks-page blocks-page-course_sales_page_v2', 'course-block block featured_products', 'block__featured-products__heading_text b-124815740-heading_color rich-text', 'block__columns__fixed b-124815742-content_width', 'featured-product-card card-style-grid block__column b-124815739-card_background_color b-124815739-card_border_color b-124815739-card_border_width b-124815739-card_border_radius b-124815739-card_text_alignment', 'block__text-wrapper b-124815737-content_width b-124815737-heading_text_color b-124815737-text_color', 'block__columns b-124815739-content_width', 'footer__inner', 'block__columns b-124815738-content_width', 'footer__wrapper', 'featured-product-card card-style-grid block__column b-124815740-card_background_color b-124815740-card_border_color b-124815740-card_border_width b-124815740-card_border_radius b-124815740-card_text_alignment', 'featured-product-card__progressbar-fill', 'navbar__header', 'block__featured-products__heading_text b-124815739-heading_color rich-text', 'block__button', 'featured-product-card card-style-grid block__column b-124815738-card_background_color b-124815738-card_border_color b-124815738-card_border_width b-124815738-card_border_radius b-124815738-card_text_alignment', 'featured-product-card__meta__item featured-product-card__author', 'block__columns b-124815740-content_width', 'featured-product-card__meta__item featured-product-card__progress hidden', 'block__featured-products__heading_text b-124815741-heading_color rich-text', 'block__featured-products__heading_text b-124815738-heading_color rich-text', 'navbar__menu'}

# %%
# Find all course summaries
#summaries = soup.find_all('div', class_="course-summary-card")
#summaries = soup.find_all('div', class_="card_overview__sRYmr")
#summaries = soup.find_all('div', class_="card_body__5gAnU")
#summaries = soup.find_all('p', class_="card_summary__uxD6t")
#summaries = soup.find_all('div')
#summaries = soup.find_all("div", {"class": "featured-product-card__content"})
titles = soup.find_all("h3", {"class": "featured-product-card__content__title"})
summaries = soup.find_all("h4", {"class": "featured-product-card__content__subtitle"})

course_objects = soup.find_all("div", {"class": "featured-product-card__content"})
for i in range(len(course_objects)):
    print(course_objects[i].select_one("h3").get_text().strip())
    print("\t", course_objects[i].select_one("h4").get_text().strip())

print('Number of Courses:', len(summaries))
print(summaries[0].text)
for i in range(len(titles)):
    print(titles[i].text.strip())
# Out:
# Introduction to Data Engineering
# 	 Introduction to Data Engineering with over 1 hour of videos including my journey here.
# Computer Science Fundamentals
# 	 A complete guide of topics and resources you should know as a Data Engineer.
# Introduction to Python
# 	 Learn all the fundamentals of Python to start coding quick
# Python for Data Engineers
# 	 Learn all the Python topics a Data Engineer needs even if you don't have a coding background
# Docker Fundamentals
# 	 Learn all the fundamental Docker concepts with hands-on examples
# Data Platform And Pipeline Design
# 	 Learn how to build data pipelines with templates and examples for Azure, GCP and Hadoop.
# Platform & Pipelines Security
# 	 Learn the important security fundamentals for Data Engineering
# Choosing Data Stores
# 	 Learn the different types of data stores and when to use which.
# Schema Design Data Stores
# 	 Learn to define schemas for SQL, NoSQL databases and Data Warehouses
# Modern Data Warehouses & Data Lakes
# 	 How to integrate a Data Lake with a Data Warehouse and query data directly from files
# Building APIs with FastAPI
# 	 Learn the fundamentals of designing, creating and deploying APIs with FastAPI and Docker
# Apache Kafka Fundamentals
# 	 Learn the fundamentals of Apache Kafka
# Apache Spark Fundamentals
# 	 Apache Spark quick start course in Python with Jupyter notebooks, DataFrames, SparkSQL and RDDs.
# Data Engineering on Databricks
# 	 Everything you need to get started with Databricks. From setup to building ETL pipelines &amp; warehousing.
# MongoDB Fundamentals
# 	 Learn how to use MongoDB
# Log Analysis with Elasticsearch
# 	 Learn how to use Elasticsearch to monitor and debug your pipelines through log indexing
# Airflow Workflow Orchestration
# 	 Learn how to orchestrate your data pipelines with Apache Airflow
# Snowflake for Data Engineers
# 	 Everything you need to get started with Snowflake
# Data Engineering on AWS
# 	 Full 5 hours course with complete example project. Building stream and batch processing pipelines on AWS.
# Machine Learning & Containerization On AWS
# 	 Build a app that analyzes the sentiment of tweets and visualizing them on a user interface hosted as container
# Data Engineering on Azure
# 	 Ingest, Store, Process, Serve and Visualize Streams of Data by Building Streaming Data Pipelines in Azure.
# Contact Tracing with Elasticsearch
# 	 Track 100,000 users in San Francisco using Elasticsearch and an interactive Streamlit user interface
# Document Streaming Project
# 	 Document Streaming with FastAPI, Kafka, Spark Streaming, MongoDB and Streamlit
# Storing & Visualizing Time Series Data with InfluxDB and Grafana
# 	 Learn how to use InfluxDB to store time series data and visualize interactive dashboards with Grafana
# Data Engineering with Hadoop
# 	 Hadoop Project with HDFS, YARN, MapReduce, Hive and Sqoop!
# Associate Data Engineer
# 	 Certify that you are job ready with the Associate Data Engineer exam
# Number of Courses: 26
#
# Introduction to Data Engineering with over 1 hour of videos including my journey here.
#
# Introduction to Data Engineering
# Computer Science Fundamentals
# Introduction to Python
# Python for Data Engineers
# Docker Fundamentals
# Data Platform And Pipeline Design
# Platform & Pipelines Security
# Choosing Data Stores
# Schema Design Data Stores
# Modern Data Warehouses & Data Lakes
# Building APIs with FastAPI
# Apache Kafka Fundamentals
# Apache Spark Fundamentals
# Data Engineering on Databricks
# MongoDB Fundamentals
# Log Analysis with Elasticsearch
# Airflow Workflow Orchestration
# Snowflake for Data Engineers
# Data Engineering on AWS
# Machine Learning & Containerization On AWS
# Data Engineering on Azure
# Contact Tracing with Elasticsearch
# Document Streaming Project
# Storing & Visualizing Time Series Data with InfluxDB and Grafana
# Data Engineering with Hadoop
# Associate Data Engineer

# %% [markdown]
# ### Step 4: Inspect the first summary to find selectors for the course name and school
# Tip: `.prettify()` is a super helpful method BeautifulSoup provides to output html in a nicely indented form! Make sure to use `print()` to ensure whitespace is displayed properly.

# %%
# print the first summary in summaries
print(course_objects[0].prettify())
# Out:
# <div class="featured-product-card__content">
#  <h3 class="featured-product-card__content__title" title="Introduction to Data Engineering">
#   Introduction to Data Engineering
#  </h3>
#  <div aria-hidden="true" class="featured-product-card__progressbar hidden">
#   <div aria-labelledby="percent-complete-1296272" aria-valuemax="100" aria-valuemin="0" class="featured-product-card__progressbar-fill" role="progressbar">
#   </div>
#  </div>
#  <h4 class="featured-product-card__content__subtitle" title="Introduction to Data Engineering with over 1 hour of videos including my journey here.">
#   Introduction to Data Engineering with over 1 hour of videos including my journey here.
#  </h4>
#  <div class="featured-product-card__meta">
#   <div class="featured-product-card__meta__item featured-product-card__author">
#    <img alt="Andreas Kretz" src="https://process.fs.teachablecdn.com/ADNupMnWyR7kCWRvm76Laz/resize=width:30,height:30/https://www.filepicker.io/api/file/Fj1QqQcCRBKKKfRizqg0"/>
#    <p class="featured-product-card__author__name" title="Andreas Kretz">
#     Andreas Kretz
#    </p>
#   </div>
#   <div aria-hidden="true" class="featured-product-card__meta__item featured-product-card__progress hidden">
#    <span class="featured-product-card__percentage" data-featured-product-id="1296272" id="percent-complete-1296272">
#     %
#    </span>
#    COMPLETE
#   </div>
#   <p data-include-vat-price='class="featured-product-card__meta__item' featured-product-card__price"="">
#   </p>
#  </div>
# </div>

# %% [markdown]
# Look for selectors that contain the courses title and school name text you want to extract. Then, use the `select_one` method on the summary object to pull out the html with those selectors. Afterwards, don't forget to do some extra cleaning to isolate the names (get rid of unnecessary html), as you saw in the last video.

# %%
# Extract course title
course_objects[0].select_one("h3").get_text().strip()
# Out:
# 'Introduction to Data Engineering'

# %%
# Extract school/description
course_objects[0].select_one("h4").get_text().strip()
# Out:
# 'Introduction to Data Engineering with over 1 hour of videos including my journey here.'

# %% [markdown]
# ### Step 5: Collect names and schools of ALL course listings
# Reuse your code from the previous step, but now in a loop to extract the name and school from every course summary in `summaries`!

# %%
courses = []
for course in course_objects:
    # append name and school of each summary to courses list
    title = course.select_one("h3").get_text().strip()
    description = course.select_one("h4").get_text().strip()
    courses.append((title, description))

# %%
# display results
print(len(courses), "course summaries found. Sample:")
courses[:20]
# Out:
# 26 course summaries found. Sample:
# [('Introduction to Data Engineering',
#   'Introduction to Data Engineering with over 1 hour of videos including my journey here.'),
#  ('Computer Science Fundamentals',
#   'A complete guide of topics and resources you should know as a Data Engineer.'),
#  ('Introduction to Python',
#   'Learn all the fundamentals of Python to start coding quick'),
#  ('Python for Data Engineers',
#   "Learn all the Python topics a Data Engineer needs even if you don't have a coding background"),
#  ('Docker Fundamentals',
#   'Learn all the fundamental Docker concepts with hands-on examples'),
#  ('Data Platform And Pipeline Design',
#   'Learn how to build data pipelines with templates and examples for Azure, GCP and Hadoop.'),
#  ('Platform & Pipelines Security',
#   'Learn the important security fundamentals for Data Engineering'),
#  ('Choosing Data Stores',
#   'Learn the different types of data stores and when to use which.'),
#  ('Schema Design Data Stores',
#   'Learn to define schemas for SQL, NoSQL databases and Data Warehouses'),
#  ('Modern Data Warehouses & Data Lakes',
#   'How to integrate a Data Lake with a Data Warehouse and query data directly from files'),
#  ('Building APIs with FastAPI',
#   'Learn the fundamentals of designing, creating and deploying APIs with FastAPI and Docker'),
#  ('Apache Kafka Fundamentals', 'Learn the fundamentals of Apache Kafka'),
#  ('Apache Spark Fundamentals',
#   'Apache Spark quick start course in Python with Jupyter notebooks, DataFrames, SparkSQL and RDDs.'),
#  ('Data Engineering on Databricks',
#   'Everything you need to get started with Databricks. From setup to building ETL pipelines &amp; warehousing.'),
#  ('MongoDB Fundamentals', 'Learn how to use MongoDB'),
#  ('Log Analysis with Elasticsearch',
#   'Learn how to use Elasticsearch to monitor and debug your pipelines through log indexing'),
#  ('Airflow Workflow Orchestration',
#   'Learn how to orchestrate your data pipelines with Apache Airflow'),
#  ('Snowflake for Data Engineers',
#   'Everything you need to get started with Snowflake'),
#  ('Data Engineering on AWS',
#   'Full 5 hours course with complete example project. Building stream and batch processing pipelines on AWS.'),
#  ('Machine Learning & Containerization On AWS',
#   'Build a app that analyzes the sentiment of tweets and visualizing them on a user interface hosted as container')]
